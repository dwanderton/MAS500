# %%
###
#
#  Did US Mainstream Media sources talk about Trump or Clinton more in September 2016?"
#    David Anderton MAS.500
#
###

import mediacloud

# importing api keys
# https://stackoverflow.com/a/34165457/3700836
# https://docs.python.org/3/library/configparser.html
import ConfigParser


configParser = ConfigParser.RawConfigParser()   
configFilePath = r'config.ini'
configParser.read(configFilePath)

print 'Currently having auth issues with API key :('

mc = mediacloud.api.MediaCloud(configParser.get('HW1', 'MediaCloudAPIKey'))
trumpResults = mc.sentenceCount('( TRUMP )', '+publish_date:[2016-09-01T00:00:00Z TO 2016-10-011T00:00:00Z} AND +tags_id_media:1')
clintonResults = mc.sentenceCount('( CLINTON )', '+publish_date:[2016-09-01T00:00:00Z TO 2016-10-011T00:00:00Z} AND +tags_id_media:1')

if trumpResults['count'] > clintonResults['count']:
    print 'Trump was talked about more in US Mainstream media in September 2016 than Clinton'
else:
    print 'Clinton was talked about more in US Mainstream media in September 2016 than Trump'
# Out:
# "02fb371511daa7757d9bf5eb9df124930d009920d32484952b4bf2f5f89b9a19"
# ---------------------------------------------------------------------------
# MCException                               Traceback (most recent call last)
# <ipython-input-6-89006dd31a82> in <module>()
#      21
#      22 mc = mediacloud.api.MediaCloud(configParser.get('HW1', 'MediaCloudAPIKey'))
# ---> 23 trumpResults = mc.sentenceCount('( TRUMP )', '+publish_date:[2016-09-01T00:00:00Z TO 2016-10-011T00:00:00Z} AND +tags_id_media:1')
#      24 clintonResults = mc.sentenceCount('( CLINTON )', '+publish_date:[2016-09-01T00:00:00Z TO 2016-10-011T00:00:00Z} AND +tags_id_media:1')
#      25
#
# /usr/local/lib/python2.7/site-packages/mediacloud/api.pyc in sentenceCount(self, solr_query, solr_filter, split, split_start_date, split_end_date, split_daily)
#     308             params['split_start_date'] = split_start_date
#     309             params['split_end_date'] = split_end_date
# --> 310         return self._queryForJson(self.V2_API_URL+'sentences/count', params)
#     311
#     312     def sentenceFieldCount(self, solr_query, solr_filter=' ', sample_size=1000, include_stats=False, field='tags_id_stories', tag_sets_id=None):
#
# /usr/local/lib/python2.7/site-packages/mediacloud/api.pyc in _queryForJson(self, url, params, http_method, json_data)
#     386         Helper that returns queries to the API as real objects
#     387         '''
# --> 388         response = self._query(url, params, http_method, json_data)
#     389         # print response.content
#     390         response_json = response.json()
#
# /usr/local/lib/python2.7/site-packages/mediacloud/api.pyc in _query(self, url, params, http_method, json_data)
#     461             self._logger.info('\t{}'.format(r.content))
#     462             msg = 'Error - got a HTTP status code of {} with the message "{}", body: {}'.format(r.status_code, r.reason, r.text)
# --> 463             raise mediacloud.error.MCException(msg, r.status_code)
#     464         return r
#     465
#
# MCException: Error - got a HTTP status code of 403 with the message "Forbidden", body: {"error":"Error(s): Invalid API key or authentication cookie. at lib/MediaWords/ActionRole/Throttled.pm line 34.\n\teval {...} called at lib/MediaWords/ActionRole/Throttled.pm line 28\n\tClass::MOP::Class:::around(CODE(0xcc9a228), Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150), MediaWords::Controller::Api::V2::Sentences=HASH(0xca33168), MediaWords=HASH(0x1040cfd8)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/x86_64-linux-gnu-thread-multi/Class/MOP/Method/Wrapped.pm line 164\n\tClass::MOP::Method::Wrapped::__ANON__(Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150), MediaWords::Controller::Api::V2::Sentences=HASH(0xca33168), MediaWords=HASH(0x1040cfd8)) called at lib/MediaWords/ActionRole/Logged.pm line 28\n\tClass::MOP::Class:::around(CODE(0xccfe990), Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150), MediaWords::Controller::Api::V2::Sentences=HASH(0xca33168), MediaWords=HASH(0x1040cfd8)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/x86_64-linux-gnu-thread-multi/Class/MOP/Method/Wrapped.pm line 164\n\tMoose::Meta::Class::__ANON__::SERIAL::21::_wrapped_execute(Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150), MediaWords::Controller::Api::V2::Sentences=HASH(0xca33168), MediaWords=HASH(0x1040cfd8)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/x86_64-linux-gnu-thread-multi/Class/MOP/Method/Wrapped.pm line 95\n\tMoose::Meta::Class::__ANON__::SERIAL::21::execute(Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150), MediaWords::Controller::Api::V2::Sentences=HASH(0xca33168), MediaWords=HASH(0x1040cfd8)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst.pm line 2052\n\teval {...} called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst.pm line 2052\n\tCatalyst::execute(MediaWords=HASH(0x1040cfd8), \"MediaWords::Controller::Api::V2::Sentences\", Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst/Plugin/Authorization/ACL.pm line 39\n\tCatalyst::Plugin::Authorization::ACL::execute(MediaWords=HASH(0x1040cfd8), \"MediaWords::Controller::Api::V2::Sentences\", Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst/Plugin/StackTrace.pm line 23\n\tCatalyst::Plugin::StackTrace::execute(MediaWords=HASH(0x1040cfd8), \"MediaWords::Controller::Api::V2::Sentences\", Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst/Action/REST.pm line 105\n\tCatalyst::Action::REST::_dispatch_rest_method(Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150), MediaWords=HASH(0x1040cfd8), \"count_GET\") called at lib/Catalyst/Action/MC_REST.pm line 44\n\tCatalyst::Action::MC_REST::dispatch(Moose::Meta::Class::__ANON__::SERIAL::21=HASH(0xcd59150), MediaWords=HASH(0x1040cfd8)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst/Controller.pm line 171\n\tCatalyst::Controller::_ACTION(MediaWords::Controller::Api::V2::Sentences=HASH(0xca33168), MediaWords=HASH(0x1040cfd8)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst/Action.pm line 358\n\tCatalyst::Action::execute(Catalyst::Action=HASH(0xcd54ba0), MediaWords::Controller::Api::V2::Sentences=HASH(0xca33168), MediaWords=HASH(0x1040cfd8)) called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst.pm line 2052\n\teval {...} called at /home/mediacloud/.perlbrew/libs/perl-system@mediacloud/lib/perl5/Catalyst.pm line 2052\n\tCatalyst::execute(MediaWords=HASH(0x1040cfd8), \"MediaWords::Controller::Api::V2::Sentences\", Catalyst::Action=HASH(0xcd54ba0)) called at /home/mediacloud/.perlbrew/libs/perl-sys ...
